# %% [markdown]
# # Imports

# %%
import pandas as pd
from pandas import DataFrame, Series 
import json

# %% [markdown]
# # Loading json file

# %%
list_of_issues_dict_data = [json.loads(line) for line in open('SPM587SP18issues.json')]

# %%
issues_df = DataFrame(list_of_issues_dict_data)

# %% [markdown]
# # Converting the dataframe object into json records

# %%
s = issues_df.to_json(orient='records')

# %% [markdown]
# # Loading the json records into variable

# %%
cont = json.loads(s)

# %% [markdown]
# # Importing Elasticsearch and helpers of elastic search

# %%
from elasticsearch import Elasticsearch, helpers

# %%
es = Elasticsearch()

# %% [markdown]
# # Inserting the data into Elastic Search (Bulk Insertion)

# %%
actions =[]
for data in cont:
    y=data['labels']
    dd = dict()
    for x in y:
        splt = x.split(':')
        l=len(splt)
        if l == 2:
            dd.update({splt[0]:splt[1]})
    data['Longitude'] = str(dd.get('Longitude'))
    data['Latitude'] = str(dd.get('Latitude'))
    action = {
        "_index": "issues",
        "_type": "issue",
        "_id" : data['issue_number'],
        "_source": data
    }
    
    actions.append(action)
    helpers.bulk(es,actions)

# %%
pooja = cont[0]
print(pooja['labels'])
dd = {k:v for k,v in (x.split(':') for x in pooja['labels']) }
# Out:
# ['Category:Inquiry', 'DetectionPhase:Field', 'OriginationPhase:Coding', 'Priority:High', 'Status:inProgress']

# %%
dd['Category']
# Out:
# 'Inquiry'

# %% [markdown]
# # Qurey to fetch all the data from elastic Search

# %%
doc = {
    'size' : 270,
    'query':{
        'match_all':{}
    }
 }
result_without_condition=es.search(index='issues',body=doc, scroll = "1h")

# %%
len(doc)
result_without_condition
# Out:
# {'_scroll_id': 'DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAADiFlZwYWNVc0FfUnhDZy0tVnNIbXVFZ2cAAAAAAAAA4xZWcGFjVXNBX1J4Q2ctLVZzSG11RWdnAAAAAAAAAOQWVnBhY1VzQV9SeENnLS1Wc0htdUVnZwAAAAAAAADlFlZwYWNVc0FfUnhDZy0tVnNIbXVFZ2cAAAAAAAAA5hZWcGFjVXNBX1J4Q2ctLVZzSG11RWdn',
#  '_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '24',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.891551',
#      'Longitude': '-87.607375',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 24,
#      'labels': ['Address:600 E GRAND AVE',
#       'Category:Inquiry',
#       'DetectionPhase:Coding',
#       'Latitude:41.891551',
#       'Longitude:-87.607375',
#       'OriginationPhase:Documentation',
#       'Priority:Major',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '22',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '40.170101',
#      'Longitude': '-92.177847',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 22,
#      'labels': ['Address:233 W JACKSON',
#       'Category:Bug',
#       'DetectionPhase:Field',
#       'Latitude:40.170101',
#       'Longitude:-92.177847',
#       'OriginationPhase:Coding',
#       'Priority:High',
#       'Status:Completed']},
#     '_type': 'issue'},
#    {'_id': '19',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.883772',
#      'Longitude': '-87.625962',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 19,
#      'labels': ['Address:119 NORTH WABASH',
#       'Category:Bug',
#       'DetectionPhase:Testing',
#       'Latitude:41.883772',
#       'Longitude:-87.625962',
#       'OriginationPhase:Field',
#       'Priority:Major',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '14',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.917164',
#      'Longitude': '-87.686965',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 14,
#      'labels': ['Address:1951 N WESTERN AVE',
#       'Category:Bug',
#       'DetectionPhase:Coding',
#       'Latitude:41.917164',
#       'Longitude:-87.686965',
#       'OriginationPhase:Documentation',
#       'Priority:Low',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '470',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'RSP18SCM19N',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-14',
#      'created_at': '2018-04-14',
#      'issue_number': 470,
#      'labels': ['Category:Enhancement',
#       'DetectionPhase:Testing',
#       'OriginationPhase:Design',
#       'Priority:Major',
#       'Status:Completed']},
#     '_type': 'issue'},
#    {'_id': '452',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'YSP18SCM40K',
#      'Latitude': '41.878693',
#      'Longitude': '-87.638924',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 452,
#      'labels': ['Address:225 S Canal St Chicago IL 60606',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.878693',
#       'Longitude:-87.638924',
#       'OriginationPhase:Requirements',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '449',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'ZSP18SCM44L',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 449,
#      'labels': ['Category:Inquiry',
#       'DetectionPhase:Field',
#       'OriginationPhase:Field',
#       'Priority:Medium',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '415',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'NSP18SCM35K',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 415,
#      'labels': ['Category:Enhancement',
#       'DetectionPhase:Testing',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '400',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'GSP18SCM22M',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 400,
#      'labels': ['Category:Inquiry',
#       'DetectionPhase:Field',
#       'OriginationPhase:Coding',
#       'Priority:High',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '397',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM01V',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 397,
#      'labels': ['Category:Inquiry',
#       'DetectionPhase:Field',
#       'OriginationPhase:Coding',
#       'Priority:Medium',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '387',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'JSP18SCM54B',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 387,
#      'labels': ['Category:Inquiry',
#       'DetectionPhase:Field',
#       'OriginationPhase:Coding',
#       'Priority:High',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '374',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM68H',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 374,
#      'labels': ['Category:Inquiry',
#       'DetectionPhase:Field',
#       'OriginationPhase:Coding',
#       'Priority:High',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '372',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM48S',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 372,
#      'labels': ['Category:Inquiry',
#       'DetectionPhase:Field',
#       'OriginationPhase:Coding',
#       'Priority:High',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '366',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'CSP18SCM33S',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 366,
#      'labels': ['Category:Bug',
#       'DetectionPhase:Testing',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '356',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'MSP18SCM38Y',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-12',
#      'issue_number': 356,
#      'labels': ['Category:Inquiry',
#       'DetectionPhase:Field',
#       'OriginationPhase:Coding',
#       'Priority:High',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '338',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'CSP18SCM41G',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-12',
#      'issue_number': 338,
#      'labels': ['Category:Bug',
#       'DetectionPhase:Testing',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '313',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'YSP18SCM92Z',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-12',
#      'created_at': '2018-04-12',
#      'issue_number': 313,
#      'labels': ['Category:Inquiry',
#       'DetectionPhase:Field',
#       'OriginationPhase:Coding',
#       'Priority:High',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '302',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'MSP18SCM51G',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-12',
#      'issue_number': 302,
#      'labels': ['Category:Bug',
#       'DetectionPhase:Testing',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '300',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM06H',
#      'Latitude': '41.838897',
#      'Longitude': '-87.646804',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-12',
#      'issue_number': 300,
#      'labels': ['Address:3020 S Halsted St Chicago IL 60608',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.838897',
#       'Longitude:-87.646804',
#       'OriginationPhase:Design',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '264',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM50W',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-16',
#      'created_at': '2018-04-11',
#      'issue_number': 264,
#      'labels': []},
#     '_type': 'issue'},
#    {'_id': '229',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'BSP18SCM69R',
#      'Latitude': '41.858415',
#      'Longitude': '-87.660926',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 229,
#      'labels': ['Address:1664 S Blue Island Ave Chicago IL 60608',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.858415',
#       'Longitude:-87.660926',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '222',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'LSP18SCM07H',
#      'Latitude': '41.893020',
#      'Longitude': ' -87.631556',
#      'State': 'closed',
#      'closed_at': '2018-04-12',
#      'created_at': '2018-04-11',
#      'issue_number': 222,
#      'labels': ['Address:600 N Clark St Chicago IL 60610',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.893020',
#       'Longitude: -87.631556',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '206',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'ASP18SCM75T',
#      'Latitude': '41.878693',
#      'Longitude': '-87.638924',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 206,
#      'labels': ['Address:225 S Canal St Chicago IL 60606',
#       'Category:Bug',
#       'Latitude:41.878693',
#       'Longitude:-87.638924',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '190',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM19P',
#      'Latitude': '41.847095',
#      'Longitude': '-87.616767',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 190,
#      'labels': ['Address:2525 S Martin Luther King Dr',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.847095',
#       'Longitude:-87.616767',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '183',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'ASP18SCM23P',
#      'Latitude': '41.847095',
#      'Longitude': '-87.616767',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 183,
#      'labels': ['Address:2525 S Martin Luther King Dr',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.847095',
#       'Longitude:-87.616767',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '172',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'MSP18SCM10S',
#      'Latitude': '41.847095',
#      'Longitude': '-87.616767',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 172,
#      'labels': ['Address:2525 S Martin Luther King Dr',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.847095',
#       'Longitude:-87.616767',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '144',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'ZSP18SCM00M',
#      'Latitude': '41.877817',
#      'Longitude': '-87.631247',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 144,
#      'labels': ['Address:111 W Jackson Blvd Chicago 60604',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.877817',
#       'Longitude:-87.631247',
#       'OriginationPhase:Design',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '120',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'JSP18SCM63X',
#      'Latitude': '41.893230',
#      'Longitude': '-87.617419',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 120,
#      'labels': ['Address:645 N MCCLURG CT',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.893230',
#       'Longitude:-87.617419',
#       'OriginationPhase:Requirements',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '116',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'MSP18SCM10S',
#      'Latitude': '41.847095',
#      'Longitude': '-87.616767',
#      'State': 'closed',
#      'closed_at': '2018-04-10',
#      'created_at': '2018-04-10',
#      'issue_number': 116,
#      'labels': ['Address:2525 S Martin Luther King Dr',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.847095',
#       'Longitude:-87.616767',
#       'OriginationPhase:Design',
#       'Priority:Medium',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '108',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM15B',
#      'Latitude': '41.877846',
#      'Longitude': '-87.631296',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 108,
#      'labels': ['Address:111 W Jackson Blvd Chicago 60604',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.877846',
#       'Longitude:-87.631296',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '105',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM30U',
#      'Latitude': '41.838897',
#      'Longitude': '-87.646804',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 105,
#      'labels': ['Address:3020 S Halsted St',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.838897',
#       'Longitude:-87.646804',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '99',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'TSP18SCM03A',
#      'Latitude': '41.838897',
#      'Longitude': '-87.646804',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 99,
#      'labels': ['Address:3020 S Halsted',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.838897',
#       'Longitude:-87.646804',
#       'OriginationPhase:Requirements',
#       'Priority:Medium',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '84',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'YSP18SCM92Z',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-10',
#      'created_at': '2018-04-10',
#      'issue_number': 84,
#      'labels': []},
#     '_type': 'issue'},
#    {'_id': '79',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'RSP18SCM13S',
#      'Latitude': '41.847095',
#      'Longitude': '-87.616767',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 79,
#      'labels': ['Address:2525 S Martin Luther King Dr',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.847095',
#       'Longitude:-87.616767',
#       'OriginationPhase:Requirements',
#       'Priority:Medium',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '73',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM67M',
#      'Latitude': '41.877846',
#      'Longitude': '-87.631296',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-10',
#      'issue_number': 73,
#      'labels': ['Address:111 W JACKSON',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.877846',
#       'Longitude:-87.631296',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved',
#       'longitude:87.631296']},
#     '_type': 'issue'},
#    {'_id': '60',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM23P',
#      'Latitude': '41.878693',
#      'Longitude': '-87.638924',
#      'State': 'closed',
#      'closed_at': '2018-04-10',
#      'created_at': '2018-04-09',
#      'issue_number': 60,
#      'labels': ['Address:225 S Canal St',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.878693',
#       'Longitude:-87.638924',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '52',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.893230',
#      'Longitude': '-87.617419',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 52,
#      'labels': ['Address:645 N MCCLURG CT',
#       'Category:Inquiry',
#       'DetectionPhase:Field',
#       'Latitude:41.893230',
#       'Longitude:-87.617419',
#       'OriginationPhase:Field',
#       'Priority:Critical',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '48',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.883772',
#      'Longitude': '-87.625962',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 48,
#      'labels': ['Address:119 NORTH WABASH',
#       'Category:Bug',
#       'DetectionPhase:Testing',
#       'Latitude:41.883772',
#       'Longitude:-87.625962',
#       'OriginationPhase:Coding',
#       'Priority:High',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '44',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.917164',
#      'Longitude': '-87.686965',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 44,
#      'labels': ['Address:1951 N WESTERN AVE',
#       'Category:Enhancement',
#       'DetectionPhase:Coding',
#       'Latitude:41.917164',
#       'Longitude:-87.686965',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '41',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.883772',
#      'Longitude': '-87.625962',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 41,
#      'labels': ['Address:119 NORTH WABASH',
#       'Category:Enhancement',
#       'DetectionPhase:Testing',
#       'Latitude:41.883772',
#       'Longitude:-87.625962',
#       'OriginationPhase:Testing',
#       'Priority:Low',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '40',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.917164',
#      'Longitude': '-87.686965',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 40,
#      'labels': ['Address:1951 N WESTERN AVE',
#       'Category:Bug',
#       'DetectionPhase:Coding',
#       'Latitude:41.917164',
#       'Longitude:-87.686965',
#       'OriginationPhase:Coding',
#       'Priority:Major',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '29',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.880982',
#      'Longitude': '-87.630553',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 29,
#      'labels': ['Address:23 S CLARK',
#       'Category:Bug',
#       'DetectionPhase:Coding',
#       'Latitude:41.880982',
#       'Longitude:-87.630553',
#       'OriginationPhase:Coding',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '26',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.917164',
#      'Longitude': '-87.686965',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 26,
#      'labels': ['Address:1951 N WESTERN AVE',
#       'Category:Enhancement',
#       'DetectionPhase:Field',
#       'Latitude:41.917164',
#       'Longitude:-87.686965',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '25',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.893230',
#      'Longitude': '-87.617419',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 25,
#      'labels': ['Address:645 N MCCLURG CT',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.893230',
#       'Longitude:-87.617419',
#       'OriginationPhase:Field',
#       'Priority:Medium',
#       'Status:Rejected']},
#     '_type': 'issue'},
#    {'_id': '12',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.893230',
#      'Longitude': 'None',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 12,
#      'labels': ['Address:645 N MCCLURG CT',
#       'Category:Inquiry',
#       'DetectionPhase:Field',
#       'Latitude:41.893230',
#       'OriginationPhase:Coding',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '10',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '40.170101',
#      'Longitude': '-92.177847',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 10,
#      'labels': ['Address:233 W JACKSON',
#       'Category:Enhancement',
#       'DetectionPhase:Coding',
#       'Latitude:40.170101',
#       'Longitude:-92.177847',
#       'OriginationPhase:Requirements',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '9',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.883772',
#      'Longitude': '-87.625962',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 9,
#      'labels': ['Address:119 NORTH WABASH',
#       'Category:Enhancement',
#       'DetectionPhase:Testing',
#       'Latitude:41.883772',
#       'Longitude:-87.625962',
#       'OriginationPhase:Field',
#       'Priority:Major',
#       'Status:Rejected']},
#     '_type': 'issue'},
#    {'_id': '8',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.883772',
#      'Longitude': '-87.625962',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 8,
#      'labels': ['Address:119 NORTH WABASH',
#       'Category:Bug',
#       'DetectionPhase:Field',
#       'Latitude:41.883772',
#       'Longitude:-87.625962',
#       'OriginationPhase:Field',
#       'Priority:Major',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '5',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.880982',
#      'Longitude': '-87.630553',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 5,
#      'labels': ['Address:23 S CLARK',
#       'Category:Enhancement',
#       'DetectionPhase:Design',
#       'Latitude:41.880982',
#       'Longitude:-87.630553',
#       'OriginationPhase:Design',
#       'Priority:High',
#       'Status:Completed']},
#     '_type': 'issue'},
#    {'_id': '445',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'RSP18SCM25A',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 445,
#      'labels': ['Category:Enhancement',
#       'DetectionPhase:Testing',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:Rejected']},
#     '_type': 'issue'},
#    {'_id': '432',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'PSP18SCM99P',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 432,
#      'labels': ['Category:Enhancement',
#       'DetectionPhase:Testing',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '396',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'ZSP18SCM00M',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 396,
#      'labels': ['Category:Inquiry',
#       'DetectionPhase:Field',
#       'OriginationPhase:Coding',
#       'Priority:High',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '367',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM30U',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 367,
#      'labels': ['Category:Inquiry',
#       'DetectionPhase:Field',
#       'OriginationPhase:Coding',
#       'Priority:High',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '363',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM56M',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 363,
#      'labels': ['Category:Inquiry',
#       'DetectionPhase:Coding',
#       'OriginationPhase:Coding',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '362',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'XSP18SCM41X',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 362,
#      'labels': ['Category:Bug',
#       'DetectionPhase:Testing',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '357',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'JSP18SCM43I',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-12',
#      'created_at': '2018-04-12',
#      'issue_number': 357,
#      'labels': ['Category: Bug', 'DetectionPhase:Testing', 'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '331',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM17K',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-12',
#      'issue_number': 331,
#      'labels': ['Category:Enhancement',
#       'DetectionPhase:Testing',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '303',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM67M',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-12',
#      'issue_number': 303,
#      'labels': ['Category:Enhancement',
#       'DetectionPhase:Testing',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '283',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'PSP18SCM54P',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-12',
#      'created_at': '2018-04-12',
#      'issue_number': 283,
#      'labels': ['Category:Inquiry',
#       'DetectionPhase:Field',
#       'OriginationPhase:Coding',
#       'Priority:High']},
#     '_type': 'issue'},
#    {'_id': '281',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'MSP18SCM65B',
#      'Latitude': '41.847095',
#      'Longitude': ' -87.616767',
#      'State': 'closed',
#      'closed_at': '2018-04-12',
#      'created_at': '2018-04-12',
#      'issue_number': 281,
#      'labels': ['Address:2525 S Martin Luther King Dr',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.847095',
#       'Longitude: -87.616767',
#       'OriginationPhase:Requirements',
#       'Priority:Medium',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '278',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM86K',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-12',
#      'issue_number': 278,
#      'labels': ['Category:Inquiry',
#       'DetectionPhase:Field',
#       'OriginationPhase:Coding',
#       'Priority:High',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '274',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'CSP18SCM33S',
#      'Latitude': ' 41.838897',
#      'Longitude': '-87.646804',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 274,
#      'labels': ['Address:3020 S Halsted St Chicago IL 60608',
#       'Category: Bug',
#       'DetectionPhase:Design',
#       'Latitude: 41.838897',
#       'Longitude:-87.646804',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '262',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'JSP18SCM63J',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 262,
#      'labels': []},
#     '_type': 'issue'},
#    {'_id': '248',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'RSP18SCM25A',
#      'Latitude': '41.893020',
#      'Longitude': '-87.631556',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 248,
#      'labels': ['Address:600 N Clark St Chicago IL 60610',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.893020',
#       'Longitude:-87.631556',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '243',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM81C',
#      'Latitude': '41.847095',
#      'Longitude': '-87.616767',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 243,
#      'labels': ['Address:2525 S Martin Luther King Dr',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.847095',
#       'Longitude:-87.616767',
#       'OriginationPhase:Design',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '224',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM68H',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 224,
#      'labels': ['Address:111 W Jackson Blvd Chicago 60604',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '221',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'ASP18SCM22G',
#      'Latitude': 'None',
#      'Longitude': '-87.630399',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 221,
#      'labels': ['Address:59 W Grand Ave Chicago IL 60654',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Lattitude:41.891368',
#       'Longitude:-87.630399',
#       'OriginationPhase:Requirements',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '191',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'ASP18SCM05A',
#      'Latitude': '41.809739',
#      'Longitude': '-87.607105',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 191,
#      'labels': ['Category:Enhancement',
#       'DetectionPhase:Coding',
#       'Latitude:41.809739',
#       'Longitude:-87.607105',
#       'OriginationPhase:Coding',
#       'Priority:Major',
#       'Status:Completed']},
#     '_type': 'issue'},
#    {'_id': '164',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'ZSP18SCM44L',
#      'Latitude': '41.847441',
#      'Longitude': '-87.679408',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 164,
#      'labels': ['Address: 2525 S King Dr Chicago IL 60616',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.847441',
#       'Longitude:-87.679408',
#       'OriginationPhase:Requirements',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '160',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM48S',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 160,
#      'labels': []},
#     '_type': 'issue'},
#    {'_id': '157',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'MSP18SCM01M',
#      'Latitude': ' 41.847095',
#      'Longitude': '-87.617419',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-11',
#      'issue_number': 157,
#      'labels': ['Address: 2525 S King Dr Chicago IL 60616',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude: 41.847095',
#       'Longitude:-87.617419',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '135',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'LSP18SCM18X',
#      'Latitude': ' 41.847095',
#      'Longitude': ' -87.616767',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 135,
#      'labels': ['Address: 2525 S King Dr Chicago IL 60616',
#       'Category:Bug',
#       'Latitude: 41.847095',
#       'Longitude: -87.616767',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '127',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'YSP18SCM71Z',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-10',
#      'created_at': '2018-04-10',
#      'issue_number': 127,
#      'labels': []},
#     '_type': 'issue'},
#    {'_id': '117',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'RSP18SCM80K',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 117,
#      'labels': ['Address:2525 S Martin Luther King Dr',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude : 41.847088',
#       'Longitude : -87.616752',
#       'OriginationPhase:Design',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '113',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'DSP18SCM14S',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-10',
#      'created_at': '2018-04-10',
#      'issue_number': 113,
#      'labels': []},
#     '_type': 'issue'},
#    {'_id': '101',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM01V',
#      'Latitude': '41.893020',
#      'Longitude': '-87.631556',
#      'State': 'closed',
#      'closed_at': '2018-04-10',
#      'created_at': '2018-04-10',
#      'issue_number': 101,
#      'labels': ['Address:600 N Clark St',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.893020',
#       'Longitude:-87.631556',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '100',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'YSP18SCM92Z',
#      'Latitude': '41.847095',
#      'Longitude': '-87.616767',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 100,
#      'labels': ['Address:2525 S Martin Luther King Dr',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.847095',
#       'Longitude:-87.616767',
#       'OriginationPhase:Requirements',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '94',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'PSP18SCM54P',
#      'Latitude': '41.877817',
#      'Longitude': '-87.631247',
#      'State': 'closed',
#      'closed_at': '2018-04-10',
#      'created_at': '2018-04-10',
#      'issue_number': 94,
#      'labels': ['Address:111 W JACKSON',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.877817',
#       'Longitude:-87.631247',
#       'OriginationPhase:Requirements',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '88',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'JSP18SCM54B',
#      'Latitude': '41.8470663',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 88,
#      'labels': ['Address : 2525 S King Dr  Chicago IL 60616',
#       'Category: Bug',
#       'Latitude:41.8470663',
#       'Longitude :-87.6867915']},
#     '_type': 'issue'},
#    {'_id': '87',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'CSP18SCM41G',
#      'Latitude': '41.877846',
#      'Longitude': '-87.631296',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 87,
#      'labels': ['Address:111 W Jackson Blvd Chicago IL 60604',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.877846',
#       'Longitude:-87.631296',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '82',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'KSP18SCM68P',
#      'Latitude': '41.951072',
#      'Longitude': '-88.119872',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 82,
#      'labels': ['Address:72 Stratford Dr Bloomingdale IL 60108',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.951072',
#       'Longitude:-88.119872',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '78',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'MSP18SCM47B',
#      'Latitude': '41.893020',
#      'Longitude': '-87.631556',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 78,
#      'labels': ['Address:600 N Clark St',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.893020',
#       'Longitude:-87.631556',
#       'OriginationPhase:Requirements',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '70',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'KSP18SCM22B',
#      'Latitude': '41.853136',
#      'Longitude': '-87.633160',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 70,
#      'labels': ['Address:2525 S Martin Luther King Drive',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.853136',
#       'Longitude:-87.633160',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '59',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'vbimaliit',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-09',
#      'created_at': '2018-04-09',
#      'issue_number': 59,
#      'labels': []},
#     '_type': 'issue'},
#    {'_id': '42',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.891551',
#      'Longitude': '-87.607375',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 42,
#      'labels': ['Address:600 E GRAND AVE',
#       'Category:Enhancement',
#       'DetectionPhase:Field',
#       'Latitude:41.891551',
#       'Longitude:-87.607375',
#       'OriginationPhase:Requirements',
#       'Priority:High',
#       'Status:Completed']},
#     '_type': 'issue'},
#    {'_id': '34',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.880982',
#      'Longitude': '-87.630553',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 34,
#      'labels': ['Address:23 S CLARK',
#       'Category:Bug',
#       'DetectionPhase:Field',
#       'Latitude:41.880982',
#       'Longitude:-87.630553',
#       'OriginationPhase:Coding',
#       'Priority:Medium',
#       'Status:Rejected']},
#     '_type': 'issue'},
#    {'_id': '33',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.883772',
#      'Longitude': '-87.625962',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 33,
#      'labels': ['Address:119 NORTH WABASH',
#       'Category:Enhancement',
#       'DetectionPhase:Testing',
#       'Latitude:41.883772',
#       'Longitude:-87.625962',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '32',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '40.170101',
#      'Longitude': '-92.177847',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 32,
#      'labels': ['Address:233 W JACKSON',
#       'Category:Inquiry',
#       'DetectionPhase:Coding',
#       'Latitude:40.170101',
#       'Longitude:-92.177847',
#       'OriginationPhase:Documentation',
#       'Priority:High',
#       'Status:Completed']},
#     '_type': 'issue'},
#    {'_id': '30',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.877817',
#      'Longitude': '-87.631247',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 30,
#      'labels': ['Address:111 W JACKSON',
#       'Category:Enhancement',
#       'DetectionPhase:Design',
#       'Latitude:41.877817',
#       'Longitude:-87.631247',
#       'OriginationPhase:Design',
#       'Priority:High',
#       'Status:Completed']},
#     '_type': 'issue'},
#    {'_id': '21',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.877817',
#      'Longitude': '-87.631247',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 21,
#      'labels': ['Address:111 W JACKSON',
#       'Category:Inquiry',
#       'DetectionPhase:Design',
#       'Latitude:41.877817',
#       'Longitude:-87.631247',
#       'OriginationPhase:Testing',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '15',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.853136',
#      'Longitude': '-87.633160',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 15,
#      'labels': ['Address:2525 S Martin Luther King Drive',
#       'Category:Inquiry',
#       'DetectionPhase:Testing',
#       'Latitude:41.853136',
#       'Longitude:-87.633160',
#       'OriginationPhase:Field',
#       'Priority:Medium',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '6',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.877817',
#      'Longitude': '-87.631247',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 6,
#      'labels': ['Address:111 W JACKSON',
#       'Category:Bug',
#       'DetectionPhase:Coding',
#       'Latitude:41.877817',
#       'Longitude:-87.631247',
#       'OriginationPhase:Coding',
#       'Priority:Critical',
#       'Status:Completed']},
#     '_type': 'issue'},
#    {'_id': '4',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.880982',
#      'Longitude': '-87.630553',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 4,
#      'labels': ['Address:23 S CLARK',
#       'Category:Enhancement',
#       'DetectionPhase:Coding',
#       'Latitude:41.880982',
#       'Longitude:-87.630553',
#       'OriginationPhase:Coding',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '2',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SPM587SP18',
#      'Latitude': '41.853136',
#      'Longitude': '-87.633160',
#      'State': 'closed',
#      'closed_at': '2018-04-06',
#      'created_at': '2018-03-30',
#      'issue_number': 2,
#      'labels': ['Address:2525 S Martin Luther King Drive',
#       'Category:Bug',
#       'DetectionPhase:Testing',
#       'Latitude:41.853136',
#       'Longitude:-87.633160',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Rejected']},
#     '_type': 'issue'},
#    {'_id': '466',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'CSP18SCM32L',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 466,
#      'labels': ['Category:Inquiry',
#       'DetectionPhase:Field',
#       'OriginationPhase:Coding',
#       'Priority:High',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '454',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'YSP18SCM35Z',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-13',
#      'created_at': '2018-04-13',
#      'issue_number': 454,
# ...
#      'created_at': '2018-04-11',
#      'issue_number': 192,
#      'labels': ['Address:2605 N Illinois St Swansea IL 62226',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:38.542048',
#       'Longitude:-89.984333',
#       'OriginationPhase:Design',
#       'Priority:Medium',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '186',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM48S',
#      'Latitude': '41.883772',
#      'Longitude': '-87.625962',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 186,
#      'labels': ['Address:119 NORTH WABASH',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.883772',
#       'Longitude:-87.625962',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '184',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'NSP18SCM35K',
#      'Latitude': '41.847095',
#      'Longitude': '-87.616767',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 184,
#      'labels': ['Address: 2525 S Martin Luther King Dr',
#       'Category:Bug',
#       'Latitude:41.847095',
#       'Longitude:-87.616767',
#       'OriginationPhase:Requirements',
#       'Priority:Critical']},
#     '_type': 'issue'},
#    {'_id': '177',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'GSP18SCM22M',
#      'Latitude': '41.847095',
#      'Longitude': ' -87.616767',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 177,
#      'labels': ['Address : 2525 S King Dr  Chicago IL 60616',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.847095',
#       'Longitude: -87.616767',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '174',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'PSP18SCM54P',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-11',
#      'issue_number': 174,
#      'labels': ['Category:Inquiry',
#       'DetectionPhase:Field',
#       'OriginationPhase:Testing',
#       'Priority:High',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '167',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'DSP18SCM14S',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 167,
#      'labels': ['Address : 2525 S King Dr  Chicago IL 60616',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude : 41.847088',
#       'Longitude : -87.616752',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '165',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'ASP18SCM22S',
#      'Latitude': '41.877846',
#      'Longitude': '-87.631296',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-11',
#      'issue_number': 165,
#      'labels': ['Address:111 W Jackson Blvd Chicago 60604',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.877846',
#       'Longitude:-87.631296',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '156',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'ZSP18SCM44L',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 156,
#      'labels': []},
#     '_type': 'issue'},
#    {'_id': '153',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'ASP18SCM05S',
#      'Latitude': '41.879094',
#      'Longitude': '-87.813483',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 153,
#      'labels': ['Address:420 Desplaines Ave Forest Park IL 60130',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.879094',
#       'Longitude:-87.813483',
#       'OriginationPhase:Design',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '152',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM41S',
#      'Latitude': '41.847095',
#      'Longitude': '-87.616767',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 152,
#      'labels': ['Address: 2525 S Martin Luther King Dr',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.847095',
#       'Longitude:-87.616767',
#       'OriginationPhase:Requirements',
#       'Priority:Medium',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '141',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM81C',
#      'Latitude': '41.847095',
#      'Longitude': '-87.616767',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-11',
#      'issue_number': 141,
#      'labels': ['Address:2525 S Martin Luther King Dr',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.847095',
#       'Longitude:-87.616767',
#       'OriginationPhase:Design',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '133',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'XSP18SCM41X',
#      'Latitude': '41.883772',
#      'Longitude': '-87.625962',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 133,
#      'labels': ['Address:119 NORTH WABASH',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.883772',
#       'Longitude:-87.625962',
#       'OriginationPhase:Design',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '122',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'VSP18SCM11J',
#      'Latitude': '41.877846',
#      'Longitude': '-87.631296',
#      'State': 'closed',
#      'closed_at': '2018-04-10',
#      'created_at': '2018-04-10',
#      'issue_number': 122,
#      'labels': ['Address:111 W Jackson Blvd Chicago IL 60604',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.877846',
#       'Longitude:-87.631296',
#       'OriginationPhase:Design',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '102',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'FSP18SCM78A',
#      'Latitude': ' 41.962450',
#      'Longitude': ' -87.837132',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 102,
#      'labels': ['Address: 4550 N Cumberland Ave Chicago IL 60656',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude: 41.962450',
#       'Longitude: -87.837132',
#       'OriginationPhase:Design',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '91',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'PSP18SCM99P',
#      'Latitude': '41.847095',
#      'Longitude': '-87.616767',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-10',
#      'issue_number': 91,
#      'labels': ['Address:2525 S Martin Luther King Dr',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.847095',
#       'Longitude:-87.616767',
#       'OriginationPhase:Design',
#       'Priority:Medium',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '76',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM01V',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-10',
#      'created_at': '2018-04-10',
#      'issue_number': 76,
#      'labels': []},
#     '_type': 'issue'},
#    {'_id': '75',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'PSP18SCM73A',
#      'Latitude': '41.852623',
#      'Longitude': '-87.611958',
#      'State': 'closed',
#      'closed_at': '2018-04-10',
#      'created_at': '2018-04-10',
#      'issue_number': 75,
#      'labels': ['Address:2301 S Lake Shore Dr',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.852623',
#       'Longitude:-87.611958',
#       'OriginationPhase:Requirements',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '74',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'SSP18SCM01V',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-10',
#      'created_at': '2018-04-10',
#      'issue_number': 74,
#      'labels': []},
#     '_type': 'issue'},
#    {'_id': '69',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'RSP18SCM25A',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-10',
#      'created_at': '2018-04-10',
#      'issue_number': 69,
#      'labels': []},
#     '_type': 'issue'},
#    {'_id': '64',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'JSP18SCM08Y',
#      'Latitude': '41.877817',
#      'Longitude': '-87.631247',
#      'State': 'closed',
#      'closed_at': '2018-04-10',
#      'created_at': '2018-04-10',
#      'issue_number': 64,
#      'labels': ['Address:111 W JACKSON',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.877817',
#       'Longitude:-87.631247',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '63',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'YSP18SCM40K',
#      'Latitude': 'None',
#      'Longitude': 'None',
#      'State': 'closed',
#      'closed_at': '2018-04-16',
#      'created_at': '2018-04-10',
#      'issue_number': 63,
#      'labels': []},
#     '_type': 'issue'},
#    {'_id': '61',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'MSP18SCM38Y',
#      'Latitude': '41.852623',
#      'Longitude': '-87.611958',
#      'State': 'closed',
#      'closed_at': '2018-04-11',
#      'created_at': '2018-04-09',
#      'issue_number': 61,
#      'labels': ['Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.852623',
#       'Longitude:-87.611958',
#       'OriginationPhase:Requirements',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '58',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'PSP18SCM08M',
#      'Latitude': '41.777989',
#      'Longitude': '-87.664548',
#      'State': 'closed',
#      'closed_at': '2018-04-10',
#      'created_at': '2018-04-09',
#      'issue_number': 58,
#      'labels': ['Address:6336 S Ashland Ave',
#       'Category:Bug',
#       'Latitude:41.777989',
#       'Longitude:-87.664548',
#       'OriginationPhase:Design',
#       'Priority:Medium',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '53',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.853136',
#      'Longitude': '-87.633160',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 53,
#      'labels': ['Address:2525 S Martin Luther King Drive',
#       'Category:Bug',
#       'DetectionPhase:Field',
#       'Latitude:41.853136',
#       'Longitude:-87.633160',
#       'OriginationPhase:Design',
#       'Priority:High',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '50',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '40.170101',
#      'Longitude': '-92.177847',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 50,
#      'labels': ['Address:233 W JACKSON',
#       'Category:Inquiry',
#       'DetectionPhase:Design',
#       'Latitude:40.170101',
#       'Longitude:-92.177847',
#       'OriginationPhase:Testing',
#       'Priority:High',
#       'Status:Completed']},
#     '_type': 'issue'},
#    {'_id': '47',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.893230',
#      'Longitude': '-87.617419',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 47,
#      'labels': ['Address:645 N MCCLURG CT',
#       'Category:Inquiry',
#       'DetectionPhase:Testing',
#       'Latitude:41.893230',
#       'Longitude:-87.617419',
#       'OriginationPhase:Field',
#       'Priority:Major',
#       'Status:pendingReview']},
#     '_type': 'issue'},
#    {'_id': '45',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.880982',
#      'Longitude': '-87.630553',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 45,
#      'labels': ['Address:23 S CLARK',
#       'Category:Enhancement',
#       'DetectionPhase:Field',
#       'Latitude:41.880982',
#       'Longitude:-87.630553',
#       'OriginationPhase:Documentation',
#       'Priority:Major',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '37',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '40.170101',
#      'Longitude': '-92.177847',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 37,
#      'labels': ['Address:233 W JACKSON',
#       'Category:Bug',
#       'DetectionPhase:Testing',
#       'Latitude:40.170101',
#       'Longitude:-92.177847',
#       'OriginationPhase:Field',
#       'Priority:High',
#       'Status:Completed']},
#     '_type': 'issue'},
#    {'_id': '31',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.883772',
#      'Longitude': '-87.625962',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 31,
#      'labels': ['Address:119 NORTH WABASH',
#       'Category:Bug',
#       'DetectionPhase:Design',
#       'Latitude:41.883772',
#       'Longitude:-87.625962',
#       'OriginationPhase:Field',
#       'Priority:Low',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '23',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.883772',
#      'Longitude': '-87.625962',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 23,
#      'labels': ['Address:119 NORTH WABASH',
#       'Category:Enhancement',
#       'DetectionPhase:Testing',
#       'Latitude:41.883772',
#       'Longitude:-87.625962',
#       'OriginationPhase:Design',
#       'Priority:Low',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '17',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.880982',
#      'Longitude': '-87.630553',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 17,
#      'labels': ['Address:23 S CLARK',
#       'Category:Enhancement',
#       'DetectionPhase:Design',
#       'Latitude:41.880982',
#       'Longitude:-87.630553',
#       'OriginationPhase:Design',
#       'Priority:High',
#       'Status:Completed']},
#     '_type': 'issue'},
#    {'_id': '11',
#     '_index': 'issues',
#     '_score': 1.0,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.891551',
#      'Longitude': '-87.607375',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 11,
#      'labels': ['Address:600 E GRAND AVE',
#       'Category:Bug',
#       'DetectionPhase:Testing',
#       'Latitude:41.891551',
#       'Longitude:-87.607375',
#       'OriginationPhase:Testing',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'}],
#   'max_score': 1.0,
#   'total': 255},
#  'timed_out': False,
#  'took': 13}

# %%
sid = result_without_condition['_scroll_id']
scroll_size = result_without_condition['hits']['total']
scroll_size
# Out:
# 255

# %%
print (sid)
print (scroll_size)
# Out:
# DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAADiFlZwYWNVc0FfUnhDZy0tVnNIbXVFZ2cAAAAAAAAA4xZWcGFjVXNBX1J4Q2ctLVZzSG11RWdnAAAAAAAAAOQWVnBhY1VzQV9SeENnLS1Wc0htdUVnZwAAAAAAAADlFlZwYWNVc0FfUnhDZy0tVnNIbXVFZ2cAAAAAAAAA5hZWcGFjVXNBX1J4Q2ctLVZzSG11RWdn
# 255

# %% [markdown]
# # Populating the data into local variable

# %%
final_location_ll = []
while(scroll_size > 0):

    for doc in result_without_condition['hits']['hits']:                   #Iterating each  results of  the qurey 
        location_ll = []
        results = doc['_source']['labels'] 
        for x in results:
            rr1 = x.split(':')
            if rr1[0]== "Latitude":
                lat_val = float(rr1[1])
                location_ll.append(lat_val )
            if rr1[0]== "Longitude":
                lon_val = float(rr1[1])
                location_ll.append(lon_val )
        if (len(location_ll)==2):
            final_location_ll.append(location_ll)
                        
                            #Appending Latitude and Longitude into the list

    result_without_condition = es.scroll(scroll_id = sid, scroll = '2m')    
    sid = result_without_condition['_scroll_id']                                 #Changing the scroll-id
    scroll_size = len(result_without_condition['hits']['hits'])  
final_location_ll
# Out:
# [[41.891551, -87.607375],
#  [40.170101, -92.177847],
#  [41.883772, -87.625962],
#  [41.917164, -87.686965],
#  [41.878693, -87.638924],
#  [41.838897, -87.646804],
#  [41.858415, -87.660926],
#  [41.89302, -87.631556],
#  [41.878693, -87.638924],
#  [41.847095, -87.616767],
#  [41.847095, -87.616767],
#  [41.847095, -87.616767],
#  [41.877817, -87.631247],
#  [41.89323, -87.617419],
#  [41.847095, -87.616767],
#  [41.877846, -87.631296],
#  [41.838897, -87.646804],
#  [41.838897, -87.646804],
#  [41.847095, -87.616767],
#  [41.877846, -87.631296],
#  [41.878693, -87.638924],
#  [41.89323, -87.617419],
#  [41.883772, -87.625962],
#  [41.917164, -87.686965],
#  [41.883772, -87.625962],
#  [41.917164, -87.686965],
#  [41.880982, -87.630553],
#  [41.917164, -87.686965],
#  [41.89323, -87.617419],
#  [40.170101, -92.177847],
#  [41.883772, -87.625962],
#  [41.883772, -87.625962],
#  [41.880982, -87.630553],
#  [41.847095, -87.616767],
#  [41.838897, -87.646804],
#  [41.89302, -87.631556],
#  [41.847095, -87.616767],
#  [41.809739, -87.607105],
#  [41.847441, -87.679408],
#  [41.847095, -87.617419],
#  [41.847095, -87.616767],
#  [41.89302, -87.631556],
#  [41.847095, -87.616767],
#  [41.877817, -87.631247],
#  [41.877846, -87.631296],
#  [41.951072, -88.119872],
#  [41.89302, -87.631556],
#  [41.853136, -87.63316],
#  [41.891551, -87.607375],
#  [41.880982, -87.630553],
#  [41.883772, -87.625962],
#  [40.170101, -92.177847],
#  [41.877817, -87.631247],
#  [41.877817, -87.631247],
#  [41.853136, -87.63316],
#  [41.877817, -87.631247],
#  [41.880982, -87.630553],
#  [41.853136, -87.63316],
#  [41.847441, -87.679408],
#  [41.852623, -87.611958],
#  [41.847095, -87.616767],
#  [41.877817, -87.631247],
#  [41.89302, -87.631556],
#  [41.877846, -87.631296],
#  [41.879094, -87.813483],
#  [42.004828, -87.67314],
#  [41.858415, -87.67314],
#  [42.004828, -87.67314],
#  [41.858415, -87.660926],
#  [41.89302, -87.631556],
#  [41.89302, -87.631556],
#  [41.838897, -87.646804],
#  [41.847095, -87.616767],
#  [41.853136, -87.63316],
#  [41.917164, -87.686965],
#  [41.891551, -87.607375],
#  [41.883772, -87.625962],
#  [41.877817, -87.631247],
#  [41.89323, -87.617419],
#  [41.883772, -87.625962],
#  [41.877817, -87.631247],
#  [41.925573, -87.649249],
#  [41.852623, -87.611958],
#  [41.852623, -87.611958],
#  [41.847095, -87.616767],
#  [41.877817, -87.631247],
#  [41.89302, -87.631556],
#  [41.878693, -87.638924],
#  [41.878693, -87.638924],
#  [41.852623, -87.611958],
#  [41.877817, -87.631247],
#  [41.879094, -87.813483],
#  [41.877817, -87.631247],
#  [38.591142, -89.984312],
#  [41.852623, -87.611958],
#  [41.891551, -87.607375],
#  [41.877817, -87.631247],
#  [41.89323, -87.617419],
#  [41.917164, -87.686965],
#  [41.877817, -87.631247],
#  [41.880982, -87.630553],
#  [41.89323, -87.617419],
#  [41.853136, -87.63316],
#  [41.852623, -87.611958],
#  [41.877846, -87.631296],
#  [41.877817, -87.631247],
#  [41.847095, -87.616767],
#  [41.809739, -87.607375],
#  [41.847441, -87.631247],
#  [41.877948, -87.634926],
#  [41.847095, -87.616767],
#  [41.847095, -87.616767],
#  [38.542048, -89.984333],
#  [41.883772, -87.625962],
#  [41.847095, -87.616767],
#  [41.847095, -87.616767],
#  [41.877846, -87.631296],
#  [41.879094, -87.813483],
#  [41.847095, -87.616767],
#  [41.847095, -87.616767],
#  [41.883772, -87.625962],
#  [41.877846, -87.631296],
#  [41.96245, -87.837132],
#  [41.847095, -87.616767],
#  [41.852623, -87.611958],
#  [41.877817, -87.631247],
#  [41.852623, -87.611958],
#  [41.777989, -87.664548],
#  [41.853136, -87.63316],
#  [40.170101, -92.177847],
#  [41.89323, -87.617419],
#  [41.880982, -87.630553],
#  [40.170101, -92.177847],
#  [41.883772, -87.625962],
#  [41.883772, -87.625962],
#  [41.880982, -87.630553],
#  [41.891551, -87.607375]]

# %%
print ("Filtered records for all match :  ", len(final_location_ll))
# Out:
# Filtered records for all match :   137

# %%
import folium
from folium import plugins
print(folium.__version__)
# Out:
# 0.5.0

# %%
without_condition_heatmap = folium.Map([41.90293279, -87.70769386], 
               zoom_start=11)
print(without_condition_heatmap)
without_condition_heatmap
# Out:
# <folium.folium.Map object at 0x0000020D23CD0780>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
without_condition_heatmap.add_child(plugins.HeatMap(final_location_ll[:40000], radius=15))
without_condition_heatmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Query 1 for DetectionPhase is Field AND Priority is Critical

# %%
doc1 = {
    'size' : 10000,
    'query':{
        'bool':{
            'must' :[{'match':{'labels':'DetectionPhase:Field'}},{'match':{'labels':'Priority:Critical'}}       
             
            ]
        }
    }
 }
result_with_condition=es.search(index='issues',body=doc1, scroll = "1h")

len(result_with_condition)

#print (result_with_condition)
# Out:
# 5

# %%
result_with_condition
# Out:
# {'_scroll_id': 'DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAADnFlZwYWNVc0FfUnhDZy0tVnNIbXVFZ2cAAAAAAAAA6BZWcGFjVXNBX1J4Q2ctLVZzSG11RWdnAAAAAAAAAOkWVnBhY1VzQV9SeENnLS1Wc0htdUVnZwAAAAAAAADqFlZwYWNVc0FfUnhDZy0tVnNIbXVFZ2cAAAAAAAAA6xZWcGFjVXNBX1J4Q2ctLVZzSG11RWdn',
#  '_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '12',
#     '_index': 'issues',
#     '_score': 2.680638,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.893230',
#      'Longitude': 'None',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 12,
#      'labels': ['Address:645 N MCCLURG CT',
#       'Category:Inquiry',
#       'DetectionPhase:Field',
#       'Latitude:41.893230',
#       'OriginationPhase:Coding',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '52',
#     '_index': 'issues',
#     '_score': 1.9169197,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.893230',
#      'Longitude': '-87.617419',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 52,
#      'labels': ['Address:645 N MCCLURG CT',
#       'Category:Inquiry',
#       'DetectionPhase:Field',
#       'Latitude:41.893230',
#       'Longitude:-87.617419',
#       'OriginationPhase:Field',
#       'Priority:Critical',
#       'Status:inProgress']},
#     '_type': 'issue'},
#    {'_id': '26',
#     '_index': 'issues',
#     '_score': 1.9169197,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.917164',
#      'Longitude': '-87.686965',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 26,
#      'labels': ['Address:1951 N WESTERN AVE',
#       'Category:Enhancement',
#       'DetectionPhase:Field',
#       'Latitude:41.917164',
#       'Longitude:-87.686965',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '38',
#     '_index': 'issues',
#     '_score': 1.63692,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.891551',
#      'Longitude': '-87.607375',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 38,
#      'labels': ['Address:600 E GRAND AVE',
#       'Category:Enhancement',
#       'DetectionPhase:Field',
#       'Latitude:41.891551',
#       'Longitude:-87.607375',
#       'OriginationPhase:Documentation',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'}],
#   'max_score': 2.680638,
#   'total': 4},
#  'timed_out': False,
#  'took': 2}

# %%
sid = result_with_condition['_scroll_id']
scroll_size = result_with_condition['hits']['total']
scroll_size
# Out:
# 4

# %% [markdown]
# # Populating the data into local variable

# %%
final_location_ll = []
while(scroll_size > 0):

    for doc in result_with_condition['hits']['hits']:                   #Iterating each  results of  the qurey 
        location_ll = []
        results = doc['_source']['labels'] 
        for x in results:
            rr1 = x.split(':')
            if rr1[0]== "Latitude":
                lat_val = float(rr1[1])
                location_ll.append(lat_val )
            if rr1[0]== "Longitude":
                lon_val = float(rr1[1])
                location_ll.append(lon_val )
        if (len(location_ll)==2):
            final_location_ll.append(location_ll)
                        
                            #Appending Latitude and Longitude into the list

    result_with_condition = es.scroll(scroll_id = sid, scroll = '2m')    
    sid = result_with_condition['_scroll_id']                                 #Changing the scroll-id
    scroll_size = len(result_with_condition['hits']['hits'])  
final_location_ll
# Out:
# [[41.89323, -87.617419], [41.917164, -87.686965], [41.891551, -87.607375]]

# %%
print ("Filtered records for query 1 :  ", len(final_location_ll))
# Out:
# Filtered records for query 1 :   3

# %% [markdown]
# # For generating HeatMap records fetched based on Query 1

# %%
with_condition_heatmap = folium.Map([41.90293279, -87.70769386], 
               zoom_start=11)

with_condition_heatmap.add_child(plugins.HeatMap(final_location_ll[:40000], radius=15))
with_condition_heatmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Query 2 for DetectionPhase is Field AND Status is Completed

# %%
doc2 = {
    'size' : 10000,
    'query':{
        'bool':{
            'must' :[{'match':{'labels':'DetectionPhase:Field'}},{'match':{'labels':'Status:Completed'}}       
             
            ]
        }
    }
 }
result_with_condition_query2=es.search(index='issues',body=doc2, scroll = "1h")

# %%
result_with_condition_query2
# Out:
# {'_scroll_id': 'DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAADsFlZwYWNVc0FfUnhDZy0tVnNIbXVFZ2cAAAAAAAAA7RZWcGFjVXNBX1J4Q2ctLVZzSG11RWdnAAAAAAAAAO4WVnBhY1VzQV9SeENnLS1Wc0htdUVnZwAAAAAAAADwFlZwYWNVc0FfUnhDZy0tVnNIbXVFZ2cAAAAAAAAA7xZWcGFjVXNBX1J4Q2ctLVZzSG11RWdn',
#  '_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '22',
#     '_index': 'issues',
#     '_score': 4.4232726,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '40.170101',
#      'Longitude': '-92.177847',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 22,
#      'labels': ['Address:233 W JACKSON',
#       'Category:Bug',
#       'DetectionPhase:Field',
#       'Latitude:40.170101',
#       'Longitude:-92.177847',
#       'OriginationPhase:Coding',
#       'Priority:High',
#       'Status:Completed']},
#     '_type': 'issue'},
#    {'_id': '42',
#     '_index': 'issues',
#     '_score': 4.1702557,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.891551',
#      'Longitude': '-87.607375',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 42,
#      'labels': ['Address:600 E GRAND AVE',
#       'Category:Enhancement',
#       'DetectionPhase:Field',
#       'Latitude:41.891551',
#       'Longitude:-87.607375',
#       'OriginationPhase:Requirements',
#       'Priority:High',
#       'Status:Completed']},
#     '_type': 'issue'},
#    {'_id': '13',
#     '_index': 'issues',
#     '_score': 3.223109,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.893230',
#      'Longitude': '-87.617419',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 13,
#      'labels': ['Address:645 N MCCLURG CT',
#       'Category:Enhancement',
#       'DetectionPhase:Field',
#       'Latitude:41.893230',
#       'Longitude:-87.617419',
#       'OriginationPhase:Coding',
#       'Priority:High',
#       'Status:Completed']},
#     '_type': 'issue'},
#    {'_id': '51',
#     '_index': 'issues',
#     '_score': 2.5170636,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.853136',
#      'Longitude': '-87.633160',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 51,
#      'labels': ['Address:2525 S Martin Luther King Drive',
#       'Category:Inquiry',
#       'DetectionPhase:Field',
#       'Latitude:41.853136',
#       'Longitude:-87.633160',
#       'OriginationPhase:Testing',
#       'Priority:High',
#       'Status:Completed']},
#     '_type': 'issue'}],
#   'max_score': 4.4232726,
#   'total': 4},
#  'timed_out': False,
#  'took': 2}

# %%
sid = result_with_condition_query2['_scroll_id']
scroll_size = result_with_condition_query2['hits']['total']
scroll_size
# Out:
# 4

# %% [markdown]
# # Populating the data into local variable

# %%
final_location_ll = []
while(scroll_size > 0):

    for doc in result_with_condition_query2['hits']['hits']:                   #Iterating each  results of  the qurey 
        location_ll = []
        results = doc['_source']['labels'] 
        for x in results:
            rr1 = x.split(':')
            if rr1[0]== "Latitude":
                lat_val = float(rr1[1])
                location_ll.append(lat_val )
            if rr1[0]== "Longitude":
                lon_val = float(rr1[1])
                location_ll.append(lon_val )
        if (len(location_ll)==2):
            final_location_ll.append(location_ll)
                        
                            #Appending Latitude and Longitude into the list

    result_with_condition_query2 = es.scroll(scroll_id = sid, scroll = '2m')    
    sid = result_with_condition_query2['_scroll_id']                                 #Changing the scroll-id
    scroll_size = len(result_with_condition_query2['hits']['hits'])  
final_location_ll
# Out:
# [[40.170101, -92.177847],
#  [41.891551, -87.607375],
#  [41.89323, -87.617419],
#  [41.853136, -87.63316]]

# %%
print ("Filtered records for query 2 :  ", len(final_location_ll))
# Out:
# Filtered records for query 2 :   4

# %% [markdown]
# # For generating HeatMap records fetched based on Query 2

# %%
with_condition_heatmap_query2 = folium.Map([41.90293279, -87.70769386], 
               zoom_start=11)

with_condition_heatmap_query2.add_child(plugins.HeatMap(final_location_ll[:40000], radius=15))
with_condition_heatmap_query2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Query 3 for DetectionPhase is Field AND Priority is Critical AND Status is Approved

# %%
doc3 = {
    'size' : 10000,
    'query':{
        'bool':{
            'must' :[{'match':{'labels':'DetectionPhase:Field'}},{'match':{'labels':'Priority:Critical'}},
                     {'match':{'labels':'Status:Approved'}}
             
            ]
        }
    }
 }
result_with_condition_query3=es.search(index='issues',body=doc3, scroll = "1h")

# %%
result_with_condition_query3
# Out:
# {'_scroll_id': 'DnF1ZXJ5VGhlbkZldGNoBQAAAAAAAADxFlZwYWNVc0FfUnhDZy0tVnNIbXVFZ2cAAAAAAAAA8hZWcGFjVXNBX1J4Q2ctLVZzSG11RWdnAAAAAAAAAPMWVnBhY1VzQV9SeENnLS1Wc0htdUVnZwAAAAAAAAD1FlZwYWNVc0FfUnhDZy0tVnNIbXVFZ2cAAAAAAAAA9BZWcGFjVXNBX1J4Q2ctLVZzSG11RWdn',
#  '_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': '12',
#     '_index': 'issues',
#     '_score': 3.1718001,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.893230',
#      'Longitude': 'None',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 12,
#      'labels': ['Address:645 N MCCLURG CT',
#       'Category:Inquiry',
#       'DetectionPhase:Field',
#       'Latitude:41.893230',
#       'OriginationPhase:Coding',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '26',
#     '_index': 'issues',
#     '_score': 2.7237563,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.917164',
#      'Longitude': '-87.686965',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 26,
#      'labels': ['Address:1951 N WESTERN AVE',
#       'Category:Enhancement',
#       'DetectionPhase:Field',
#       'Latitude:41.917164',
#       'Longitude:-87.686965',
#       'OriginationPhase:Requirements',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'},
#    {'_id': '38',
#     '_index': 'issues',
#     '_score': 2.4814277,
#     '_source': {'Author': 'HSP18SCM69D',
#      'Latitude': '41.891551',
#      'Longitude': '-87.607375',
#      'State': 'open',
#      'closed_at': None,
#      'created_at': '2018-04-09',
#      'issue_number': 38,
#      'labels': ['Address:600 E GRAND AVE',
#       'Category:Enhancement',
#       'DetectionPhase:Field',
#       'Latitude:41.891551',
#       'Longitude:-87.607375',
#       'OriginationPhase:Documentation',
#       'Priority:Critical',
#       'Status:Approved']},
#     '_type': 'issue'}],
#   'max_score': 3.1718001,
#   'total': 3},
#  'timed_out': False,
#  'took': 2}

# %%
sid = result_with_condition_query3['_scroll_id']
scroll_size = result_with_condition_query3['hits']['total']
scroll_size
# Out:
# 3

# %% [markdown]
# # Populating the data into local variable

# %%
final_location_ll = []
while(scroll_size > 0):

    for doc in result_with_condition_query3['hits']['hits']:                   #Iterating each  results of  the qurey 
        location_ll = []
        results = doc['_source']['labels'] 
        for x in results:
            rr1 = x.split(':')
            if rr1[0]== "Latitude":
                lat_val = float(rr1[1])
                location_ll.append(lat_val )
            if rr1[0]== "Longitude":
                lon_val = float(rr1[1])
                location_ll.append(lon_val )
        if (len(location_ll)==2):
            final_location_ll.append(location_ll)
                        
                            #Appending Latitude and Longitude into the list

    result_with_condition_query3 = es.scroll(scroll_id = sid, scroll = '2m')    
    sid = result_with_condition_query3['_scroll_id']                                 #Changing the scroll-id
    scroll_size = len(result_with_condition_query3['hits']['hits'])  
final_location_ll
# Out:
# [[41.917164, -87.686965], [41.891551, -87.607375]]

# %%
print ("Filtered records for query 3 : ", len(final_location_ll))
# Out:
# Filtered records for query 3 :  2

# %% [markdown]
# # For generating HeatMap records fetched based on Query 3

# %%
with_condition_heatmap_query3 = folium.Map([41.90293279, -87.70769386], 
               zoom_start=11)

with_condition_heatmap_query3.add_child(plugins.HeatMap(final_location_ll[:40000], radius=15))
with_condition_heatmap_query3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Query 4 for DetectionPhase is Field AND Priority is Critical or High AND Status is Approved or inProgress

# %%
doc4 = {
    'size' : 10000,
    'query':{'bool':{'must' :[{'match':{'labels':'DetectionPhase:Field'}},{ 'bool': { 
        'should': [{'match': {'labels': 'Priority:Critical'}},{'match':{'labels':'Priority:High'}}]} },
                { 'bool': { 'should': [{'match': {'labels': 'Status:Approved'}},{'match':{'labels':'Status:inProgress'}}]} }
            ]}} }
result_with_condition_query4=es.search(index='issues',body=doc4, scroll = "1h")
#print (result_with_condition)

# %%
sid = result_with_condition_query4['_scroll_id']
scroll_size = result_with_condition_query4['hits']['total']
scroll_size
# Out:
# 24

# %% [markdown]
# # Populating the data into local variable

# %%
final_location_ll = []
while(scroll_size > 0):

    for doc in result_with_condition_query4['hits']['hits']:                   #Iterating each  results of  the qurey 
        location_ll = []
        results = doc['_source']['labels'] 
        for x in results:
            rr1 = x.split(':')
            if rr1[0]== "Latitude":
                lat_val = float(rr1[1])
                location_ll.append(lat_val )
            if rr1[0]== "Longitude":
                lon_val = float(rr1[1])
                location_ll.append(lon_val )
        if (len(location_ll)==2):
            final_location_ll.append(location_ll)
                        
                            #Appending Latitude and Longitude into the list

    result_with_condition_query4 = es.scroll(scroll_id = sid, scroll = '2m')    
    sid = result_with_condition_query4['_scroll_id']                                 #Changing the scroll-id
    scroll_size = len(result_with_condition_query4['hits']['hits'])  
final_location_ll
# Out:
# [[41.89323, -87.617419],
#  [41.853136, -87.63316],
#  [41.917164, -87.686965],
#  [41.891551, -87.607375]]

# %%
print ("Filtered records for query 4 :  ", len(final_location_ll))
# Out:
# Filtered records for query 4 :   4

# %% [markdown]
# # For generating HeatMap records fetched based on Query 4

# %%
with_condition_heatmap_query4= folium.Map([41.90293279, -87.70769386], 
               zoom_start=11)
with_condition_heatmap_query4.add_child(plugins.HeatMap(final_location_ll[:40000], radius=15))
with_condition_heatmap_query4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Query 5 for Create Folium HeatMap for all locations that got at least 5 issues create for the same location (latitude, Longitude)

# %%
doc = {
    'size' : 0,
    'query':{
        'bool':{
            'must_not' :[{'match':{'Latitude':'None'}},{'match':{'Longitude':'None'}} ]} },
   "aggs" : {"latitude": {"terms" : { "field" : "Latitude.keyword" ,"min_doc_count": 5,"order" : { "_count" : "asc" }},
            "aggs":{"longitude":{"terms" : { "field" : "Longitude.keyword","min_doc_count": 5}}}            }
           }}
result_with_condition_query5=es.search(index='issues',body=doc)
result_with_condition_query5
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'aggregations': {'latitude': {'buckets': [{'doc_count': 5,
#      'key': '40.170101',
#      'longitude': {'buckets': [{'doc_count': 5, 'key': '-92.177847'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}},
#     {'doc_count': 5,
#      'key': '41.877846',
#      'longitude': {'buckets': [{'doc_count': 5, 'key': '-87.631296'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}},
#     {'doc_count': 5,
#      'key': '41.878693',
#      'longitude': {'buckets': [{'doc_count': 5, 'key': '-87.638924'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}},
#     {'doc_count': 5,
#      'key': '41.891551',
#      'longitude': {'buckets': [{'doc_count': 5, 'key': '-87.607375'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}},
#     {'doc_count': 6,
#      'key': '41.853136',
#      'longitude': {'buckets': [{'doc_count': 6, 'key': '-87.633160'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}},
#     {'doc_count': 6,
#      'key': '41.917164',
#      'longitude': {'buckets': [{'doc_count': 6, 'key': '-87.686965'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}},
#     {'doc_count': 7,
#      'key': '41.880982',
#      'longitude': {'buckets': [{'doc_count': 7, 'key': '-87.630553'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}},
#     {'doc_count': 7,
#      'key': '41.893020',
#      'longitude': {'buckets': [{'doc_count': 6, 'key': '-87.631556'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}},
#     {'doc_count': 7,
#      'key': '41.893230',
#      'longitude': {'buckets': [{'doc_count': 7, 'key': '-87.617419'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}},
#     {'doc_count': 8,
#      'key': '41.852623',
#      'longitude': {'buckets': [{'doc_count': 8, 'key': '-87.611958'}],
#       'doc_count_error_upper_bound': 0,
#       'sum_other_doc_count': 0}}],
#    'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 44}},
#  'hits': {'hits': [], 'max_score': 0.0, 'total': 137},
#  'timed_out': False,
#  'took': 19}

# %% [markdown]
# # Populating the data into local variable

# %%
list_query_5 = []
for ele in result_with_condition_query5['aggregations']['latitude']['buckets']:
    lst_q5 = []
    d = dict(ele)
    lst_q5.append(float(d['key']))
    d1 = dict(d['longitude'])
    for i in d1['buckets']:
        dict(i)
        lst_q5.append(float(i['key']))
    list_query_5.append(lst_q5)

# %% [markdown]
# # For generating HeatMap records fetched based on Query 5

# %%
with_condition_heatmap_quer5 = folium.Map([41.9029,-87.7070],zoom_start=11)
print("Filtered records for query 5 :  ",len(list_query_5))
# Out:
# Filtered records for query 5 :   10

# %%
with_condition_heatmap_quer5.add_child(plugins.HeatMap(list_query_5[:40000], radius=15))
with_condition_heatmap_quer5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
